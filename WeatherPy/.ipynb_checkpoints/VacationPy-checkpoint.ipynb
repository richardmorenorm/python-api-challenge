# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json
# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df
# Out:
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          0      castro -24.7911  -50.0119     17.50        84           9
# 1          1       tabat  -2.6350  115.2274     26.02        85         100
# 2          2       pevek  69.7008  170.3133    -35.13        96         100
# 3          3       airai  -8.9266  125.4092     20.41        73          89
# 4          4     qaanaaq  77.4840  -69.3632    -18.74        52          95
# ..       ...         ...      ...       ...       ...       ...         ...
# 574      574        ahar  38.4774   47.0699     -1.48        84         100
# 575      575       seoul  37.5683  126.9778      2.76        87          20
# 576      576   covington  39.0837  -84.5086      9.08        69          40
# 577      577      igarka  67.4667   86.5833    -20.94        99         100
# 578      578  taguatinga -12.3857  -46.5711     24.68        71          20
#
#      Wind Speed Country        Date
# 0          2.52      BR  1675646177
# 1          0.39      ID  1675646179
# 2          1.56      RU  1675645802
# 3          1.55      TL  1675645787
# 4          1.14      GL  1675645715
# ..          ...     ...         ...
# 574        3.15      IR  1675646565
# 575        0.51      KR  1675646352
# 576        3.09      US  1675646565
# 577        2.29      RU  1675646566
# 578        0.63      BR  1675646567
#
# [579 rows x 10 columns]

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    color = 'City'
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_city_df = city_data_df[city_data_df["Max Temp"] < 27]
ideal_city_df = city_data_df[city_data_df["Max Temp"] > 21]
ideal_city_df = city_data_df[city_data_df["Cloudiness"] == 0]



# Drop any rows with null values
ideal_city_df = ideal_city_df.dropna()

# Display sample data
ideal_city_df
# Out:
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 7          7       jumla  29.2747   82.1838      2.10        50           0
# 8          8   busselton -33.6500  115.3333     23.44        59           0
# 22        22   fairbanks  64.8378 -147.7164    -13.84        81           0
# 29        29  coahuayana  18.7333 -103.6833     23.24        75           0
# 40        40   carnarvon -24.8667  113.6333     26.87        62           0
# ..       ...         ...      ...       ...       ...       ...         ...
# 553      553     pericos  25.0500 -107.7000     25.20        51           0
# 554      554      lompoc  34.6391 -120.4579     13.80        80           0
# 558      558      mandan  46.8267 -100.8896     -0.35        82           0
# 560      560      helena  46.5927 -112.0361      4.44        77           0
# 572      572  vila velha -20.3297  -40.2925     27.19        84           0
#
#      Wind Speed Country        Date
# 7          1.85      NP  1675645867
# 8          5.15      AU  1675645782
# 22         2.57      US  1675646102
# 29         1.67      MX  1675646074
# 40         7.38      AU  1675646159
# ..          ...     ...         ...
# 553        2.53      MX  1675646530
# 554        6.69      US  1675645918
# 558        4.47      US  1675646540
# 560        2.57      US  1675646543
# 572        5.66      BR  1675645961
#
# [88 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''
# YOUR CODE HERE

# Display sample data
hotel_df
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 7         jumla      NP  29.2747   82.1838        50
# 8     busselton      AU -33.6500  115.3333        59
# 22    fairbanks      US  64.8378 -147.7164        81
# 29   coahuayana      MX  18.7333 -103.6833        75
# 40    carnarvon      AU -24.8667  113.6333        62
# ..          ...     ...      ...       ...       ...        ...
# 553     pericos      MX  25.0500 -107.7000        51
# 554      lompoc      US  34.6391 -120.4579        80
# 558      mandan      US  46.8267 -100.8896        82
# 560      helena      US  46.5927 -112.0361        77
# 572  vila velha      BR -20.3297  -40.2925        84
#
# [88 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel", 
    "limit":20,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row['Lng']
    latitude = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# jumla - nearest hotel: Amar Sandesh Guesthouse
# busselton - nearest hotel: Broadwater Beach Resort
# fairbanks - nearest hotel: Westmark Fairbanks Hotel
# coahuayana - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# madison - nearest hotel: 106 Jefferson Huntsville, Curio Collection by Hilton
# ozoir-la-ferriere - nearest hotel: B&B Hôtel
# cape town - nearest hotel: Townhouse Hotel
# lata - nearest hotel: Residencial Botânico
# waynesboro - nearest hotel: Quality Inn
# bethel - nearest hotel: Hampton Inn Danbury
# saint-pierre - nearest hotel: Tropic Hotel
# quechultenango - nearest hotel: No hotel found
# denia - nearest hotel: MR Hotel Costa Blanca
# saldanha - nearest hotel: Hoedjesbaai
# aswan - nearest hotel: Yaseen hotel
# doha - nearest hotel: Al MIrqab
# cayenne - nearest hotel: Central Hôtel
# dalbandin - nearest hotel: SF Al-dawood Restaurant
# bushehr - nearest hotel: هتل رستوران سیراف
# chuy - nearest hotel: Alerces
# tura - nearest hotel: No hotel found
# half moon bay - nearest hotel: Half Moon Bay Inn
# xichang - nearest hotel: No hotel found
# clyde river - nearest hotel: No hotel found
# rapid valley - nearest hotel: Sleep Inn & Suites
# sebring - nearest hotel: Residence Inn by Marriott Sebring
# san patricio - nearest hotel: No hotel found
# laguna - nearest hotel: Holiday Inn Express & Suites
# isla vista - nearest hotel: The Club & Guest House
# flinders - nearest hotel: Nova Kiama
# bhinmal - nearest hotel: No hotel found
# coquimbo - nearest hotel: Hotel Iberia
# muscatine - nearest hotel: Travelodge Inn & Suites by Wyndham Muscatine
# yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# west memphis - nearest hotel: La Quinta Inn & Suites
# comodoro rivadavia - nearest hotel: No hotel found
# salobrena - nearest hotel: Hostal La Paloma
# sidi ali - nearest hotel: Motel Kadi
# san francisco menendez - nearest hotel: Hotel La Hachadura
# guerrero - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# dungarpur - nearest hotel: No hotel found
# general roca - nearest hotel: Hotel Austral
# sitrah - nearest hotel: No hotel found
# hammond - nearest hotel: Fairfield Inn & Suites by Marriott Chicago Southeast/Hammond
# zhob - nearest hotel: No hotel found
# susanville - nearest hotel: SureStay Plus Hotel By Best Western Susanville
# pampa - nearest hotel: AmericInn
# baghdad - nearest hotel: AL Bedaa Hotel
# valparaiso - nearest hotel: Ibis Hotel
# quesnel - nearest hotel: Quality Inn
# tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# bikaner - nearest hotel: Hotel Taj Restaurant
# acapulco - nearest hotel: Hotel del Valle
# matamoros - nearest hotel: No hotel found
# koulikoro - nearest hotel: No hotel found
# fort nelson - nearest hotel: Fort Nelson Hotel
# general pico - nearest hotel: Euskadi Hotel
# kokkola - nearest hotel: Hotelli Seurahuone
# dali - nearest hotel: 风花雪月大酒店
# maryville - nearest hotel: Main lodge
# pochutla - nearest hotel: Posada San Jose
# amlagora - nearest hotel: No hotel found
# broken hill - nearest hotel: Ibis Styles
# cabo san lucas - nearest hotel: Comfort Rooms
# artesia - nearest hotel: Days Inn & Suites by Wyndham Artesia
# wagga wagga - nearest hotel: The Astor
# pijijiapan - nearest hotel: No hotel found
# shahdadkot - nearest hotel: No hotel found
# ulcinj - nearest hotel: Hostel Pirate
# angleton - nearest hotel: No hotel found
# vaasa - nearest hotel: Sokos Hotel Vaakuna
# rafaela - nearest hotel: Toscano
# rudbar - nearest hotel: No hotel found
# casablanca - nearest hotel: Hotel de Prince de Paris
# filadelfia - nearest hotel: The Ritz-Carlton, Philadelphia
# kano - nearest hotel: Gab Hotel
# owensboro - nearest hotel: Hampton
# griffith - nearest hotel: Residence Inn by Marriott Chicago Southeast/Hammond
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# carbondale - nearest hotel: Quality Inn
# panzhihua - nearest hotel: 木棉花酒店
# pericos - nearest hotel: No hotel found
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# mandan - nearest hotel: North Country Inn
# helena - nearest hotel: DoubleTree
# vila velha - nearest hotel: Hotel Prainha
#            City Country      Lat       Lng  Humidity  \
# 7         jumla      NP  29.2747   82.1838        50
# 8     busselton      AU -33.6500  115.3333        59
# 22    fairbanks      US  64.8378 -147.7164        81
# 29   coahuayana      MX  18.7333 -103.6833        75
# 40    carnarvon      AU -24.8667  113.6333        62
# ..          ...     ...      ...       ...       ...
# 553     pericos      MX  25.0500 -107.7000        51
# 554      lompoc      US  34.6391 -120.4579        80
# 558      mandan      US  46.8267 -100.8896        82
# 560      helena      US  46.5927 -112.0361        77
# 572  vila velha      BR -20.3297  -40.2925        84
#
#                                         Hotel Name
# 7                          Amar Sandesh Guesthouse
# 8                          Broadwater Beach Resort
# 22                        Westmark Fairbanks Hotel
# 29                                  No hotel found
# 40                                  No hotel found
# ..                                             ...
# 553                                 No hotel found
# 554  Embassy Suites by Hilton Lompoc Central Coast
# 558                              North Country Inn
# 560                                     DoubleTree
# 572                                  Hotel Prainha
#
# [88 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
# Configure the map plot
map_plot = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    color = 'City',
    hover_cols=['Country', 'Hotel Name']
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
